# %% [markdown]
# # Uso del laboratorio 2026 V.2 (24 preguntas)
#
#
# ## Mensaje incial
#
# Cuando se procesan datos que involucran participación humana en su *inputación* (del inglés *input*) suele haber errores en la carga. Los mismos pueden deberse a distracciones, falta de comunicación (por ejemplo, usó el punto decimal en vez de la coma) o falta de comprensión. Es nuestro deber tomar decisiones sobre qué hacer con las entradas afectadas. Naturalmente, deberemos justificar nuestras decisiones.
#
# ---
#
# ### 1. Limpiar DataFrame
#
# #### 1.1 Dropear columna de marca temporal
# Observar que realizar esto al principio es arbitrario. Podría ser útil conservar la marca temporal si luego vamos a, por ejemplo, filtrar duplicados según la última imputación.
#
# #### 1.2 Redefinir columnas
# La lista completa de columnas en orden de la encuesta (se dropearon previamente Correo y Encuestador):
#
# ```python
# df.columns = ['Apellido', 'Nombre', 'Edad', 'Carrera', 'Materias regularizadas', 'Materias aprobadas', 'Materias promocionadas', 'Materias previas', 'Celular PC', 'Tipo de máquina', 'Experiencia máquina', 'Minutos laboratorio', 'Minutos externo', 'Teclado ok', 'Teclado externo', 'Experiencia teclado', 'Puntaje máquina', 'Puntaje Labo', 'Ponderación labo', 'Mejora a considerar', 'Propuestas labo', 'Factibilidad propuesta']
# ```
#
# #### 1.3 Filtrar duplicados por nombre ficticio
#
# ## 2. Analizar Inconsistencia Puntaje/Experiencia (adaptada de la versión anterior)
#
# **Relación:** ¿La gente que dice sufrir con el teclado puntúa bajo las máquinas, o hay inconsistencias?
#
# **Responder:** ¿Qué proporción de encuestados es inconsistente o altamente inconsistente? ¿Qué conclusiones sacás sobre la confiabilidad de las respuestas?
#
# ## 3. Tiempo de encendido vs. puntaje de experiencia de uso de máquina
# **Relación:** ¿A mayor tiempo de encendido, menor puntaje?
#
# Cuando trabajamos con dos columnas numéricas podemos calcular el **coeficiente de
# correlación de Pearson**. Se propone investigar sobre el mismo para poder usarlo en el análisis. Como introducción breve, el coeficiente de correlación es un número entre -1 y 1 que mide cómo están relacionadas dos variables *de cierta forma* y con qué fuerza:
#
#     - Cerca de 1: relación directa — cuando una sube, la otra sube.
#     - Cerca de -1: relación inversa — cuando una sube, la otra baja.
#     - Cerca de 0: no hay relación.
#     - Mientras más cerca de 1 o -1, más fuerte es la relación.
#
#     Ojo: correlación no implica causalidad. Mide si las variables se mueven juntas,
#     no dice que una sea la causa de la otra.
#
#     Responder:
#
#     1. ¿A partir de cuántos minutos la satisfacción empieza a caer?
#     2. Calculá el coeficiente de correlación entre minutos y puntaje. ¿Qué dirección
#        tiene la relación? ¿Qué tan fuerte es?
#     3. Describí en una línea la relación entre el tiempo de encendido y el puntaje
#        de experiencia.
#
# ## 4. Brecha de expectativas: laboratorio vs. equipo propio. (Debe haber: `.scatterplot()`)
# **Relación:** ¿La gente tolera más demora en el laboratorio que en su propia máquina?
#
# **Hipótesis:** Naturalizamos la mediocridad institucional. Si tu PC tarda 10 min → desastre. Si el laboratorio tarda 10 min → "bueno, es el labo".
#
# **⚠️ Problema:** Solo funciona para quienes respondieron **ambas** preguntas de minutos (p14 y p15). Quien nunca usó laboratorio o nunca usó máquina ajena no tiene par para comparar. De acuerdo a cómo sean las respuestas el análisis puede extenderse. Por ejemplo, ¿Qué pasa si son muchos los que respondieron de forma sospechosa o inconsistente?
#
#
# **Responder:** ¿Quiénes normalizan más la demora del laboratorio? Segmentar por `Carrera`, `Tipo de máquina`, `Celular PC`. Describí en 2-3 líneas qué patrón encontraste. ¿El filtro inicial introdujo algún sesgo?
#
# ## 5. Carrera y perfil del que elige mejorar el SO (Debe haber: `.plot.bar()`)
# **Relación:** ¿Los de carreras más técnicas eligen distinto que los de humanidades? Si no hay diferencia por carrera, ¿hay alguna otra cualidad que compartan los que eligen "Cambiar SO"?
#
# **Responder:** ¿Hay una tendencia por carrera? Si la hay, describila. Si no, ¿los que eligen "Cambiar SO" comparten alguna cualidad en común (tipo de máquina, experiencia, uso del celular)? ¿O son transversales? En cualquier caso, ¿qué conclusión sacás?
# Los que respondieron "Desconozco", ¿comparten alguna cualidad en común?
